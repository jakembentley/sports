# %%
import pandas
import nfl_data_py as nfl
import plotly.graph_objects as go

# %% [markdown]
# ## Primed to Pop-Off or Retire
#
# The NFL is a chaotic mess. There are colloqial truths about player performance: NFL careers are typically short, especially for running backs. If youre a fantasy football manager, you've probably encountered this before. The old addage is don't trust a running back whos at or over 30. Yet you find some outliers from time-to-time. Some prolific performers who were able to have long standing careers. Frank Gore and Adrian Petereson come to mind.
#
# But if you look at the performance this year you'll see many players whose performance has dwindled. Most prominently, Eziekel Elliot has looked markedly worse than Tony Pollard. A rash of quarterbacks have also fallen prey to father time. The colts are still cursed to start a veteran quarterback whose right arm could easily have been cast as the lead in Memento. Russell Wilson, once heralded as elite. has a severe case of altitude sickness. Carson Bench is, well, Carson Bench.
#
# Whats the truth behind this performance? When can we expect father time to come knocking?

# %%
def get_year_performance(year, position):
    '''
    get and aggregate overall performance for a certain position over the course of a year
    position can be 'WR', 'QB', 'TE', 'RB'
    '''
    #import data
    pbp = nfl.import_pbp_data([year])
    players = nfl.import_rosters([year])
    teams = nfl.import_team_desc()
    
    #filter for regular season
    pbp = pbp[pbp["season_type"] == 'REG']
    pbp = pbp[pbp["two_point_attempts"] == False]
    pbp = pbp[pbp["play_type"] == 'run' or pbp["play_type"] == 'pass']
    
    '''
    player_id flags of interest: rusher_player_id, passer_player_id, reciever_player_id
    '''

# %%
pbp = nfl.import_pbp_data([2021])
# Out:
# 2021 done.
# Downcasting floats.
# C:\Users\sydmb\anaconda3\envs\sports\lib\site-packages\nfl_data_py\__init__.py:137: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   plays.loc[:, cols] = plays.loc[:, cols].astype(numpy.float32)

# %%
pbp["play_type"].unique()
# Out:
# array([None, 'kickoff', 'run', 'pass', 'punt', 'no_play', 'field_goal',
#        'extra_point', 'qb_spike', 'qb_kneel'], dtype=object)

# %%
pbp = pbp[pbp["play_type"] == 'pass']

# %%
# Out:
# play_id
# game_id
# old_game_id
# home_team
# away_team
# season_type
# week
# posteam
# posteam_type
# defteam
# side_of_field
# yardline_100
# game_date
# quarter_seconds_remaining
# half_seconds_remaining
# game_seconds_remaining
# game_half
# quarter_end
# drive
# sp
# qtr
# down
# goal_to_go
# time
# yrdln
# ydstogo
# ydsnet
# desc
# play_type
# yards_gained
# shotgun
# no_huddle
# qb_dropback
# qb_kneel
# qb_spike
# qb_scramble
# pass_length
# pass_location
# air_yards
# yards_after_catch
# run_location
# run_gap
# field_goal_result
# kick_distance
# extra_point_result
# two_point_conv_result
# home_timeouts_remaining
# away_timeouts_remaining
# timeout
# timeout_team
# td_team
# td_player_name
# td_player_id
# posteam_timeouts_remaining
# defteam_timeouts_remaining
# total_home_score
# total_away_score
# posteam_score
# defteam_score
# score_differential
# posteam_score_post
# defteam_score_post
# score_differential_post
# no_score_prob
# opp_fg_prob
# opp_safety_prob
# ...

# %%
players = nfl.import_rosters([2021])

# %%
for col in players.columns.unique():
    print(col)
# Out:
# season
# team
# position
# depth_chart_position
# jersey_number
# status
# player_name
# first_name
# last_name
# birth_date
# height
# weight
# college
# player_id
# espn_id
# sportradar_id
# yahoo_id
# rotowire_id
# pff_id
# pfr_id
# fantasy_data_id
# sleeper_id
# years_exp
# headshot_url
# ngs_position
# week
# game_type
# status_description_abbr
# football_name
# esb_id
# gsis_it_id
# smart_id
# entry_year
# rookie_year
# draft_club
# draft_number

# %%
players["position"].unique()
# Out:
# array(['DB', 'DL', 'LB', 'OL', 'QB', 'RB', 'SPEC', 'TE', 'WR'],
#       dtype=object)
